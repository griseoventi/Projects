# %% [markdown]
# Работа с данными
#
# Предположим в июле провели специальную акцию, направленную на улучшение ретеншена. Новым юзерам слали письмо с купоном. Сработала ли акция?

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\Lily_B\Documents\аналитика на python\analyst_test_transactions_db.csv')

# %%
df.head()
# Out:
#    user_id  order_id    reg_date transaction_date  revenue
# 0    57562   94545.0  2013-12-22       2015-07-16     1088
# 1    40047   81824.0  2013-11-24       2015-01-19     1027
# 2    48153  144851.0  2015-07-03       2015-10-29      601
# 3    54591  116111.0  2013-07-12       2015-04-30      881
# 4    39789  134943.0  2013-05-25       2015-07-21      984

# %%
len(df)
# Out:
# 76857

# %%
df.dtypes
# Out:
# user_id               int64
# order_id            float64
# reg_date             object
# transaction_date     object
# revenue               int64
# dtype: object

# %% [markdown]
# Преобразуем дату.

# %%
df['reg_date'] = pd.to_datetime(df['reg_date'],format='%Y-%m-%d')
df['transaction_date'] = pd.to_datetime(df['transaction_date'],format='%Y-%m-%d')

# %% [markdown]
# Нужен июль 2015. Только в нем есть транзакции.

# %%
df['reg_date'].agg(['min','max'])
# Out:
# min   1900-01-01
# max   2015-11-20
# Name: reg_date, dtype: datetime64[ns]

# %%
df['reg_month'] = df['reg_date'].astype('datetime64[M]')

# %% [markdown]
# Посмотрим количество уникальных пользователей.

# %%
df.groupby(['reg_month'])['user_id'].agg(['count','nunique'])
# Out:
#             count  nunique
# reg_month
# 1900-01-01     53       53
# 2012-02-01      9        9
# 2012-03-01    362      361
# 2012-04-01    370      370
# 2012-05-01    301      301
# 2012-06-01    445      443
# 2012-07-01    370      369
# 2012-08-01    271      269
# 2012-09-01    356      355
# 2012-10-01    367      367
# 2012-11-01    272      272
# 2012-12-01    538      535
# 2013-01-01    418      418
# 2013-02-01    654      653
# 2013-03-01   1161     1158
# 2013-04-01    844      837
# 2013-05-01   1081     1076
# 2013-06-01    941      931
# 2013-07-01   1103     1097
# 2013-08-01   1201     1191
# 2013-09-01   1004      994
# 2013-10-01    822      815
# 2013-11-01   1136     1124
# 2013-12-01   1584     1566
# 2014-01-01   1424     1406
# 2014-02-01   1339     1329
# 2014-03-01   1520     1505
# 2014-04-01   1625     1602
# 2014-05-01   1514     1493
# 2014-06-01   1911     1892
# 2014-07-01   1811     1793
# 2014-08-01   2395     2348
# 2014-09-01   2593     2544
# 2014-10-01   2967     2909
# 2014-11-01   2946     2883
# 2014-12-01   4713     4556
# 2015-01-01   4195     4083
# 2015-02-01   3652     3570
# 2015-03-01   3646     3557
# 2015-04-01   3411     3327
# 2015-05-01   2706     2652
# 2015-06-01   3568     3477
# 2015-07-01   4376     4236
# 2015-08-01   3319     3230
# 2015-09-01   2422     2398
# 2015-10-01   2239     2209
# 2015-11-01    902      898

# %%
df['transaction_month'] = df['transaction_date'].astype('datetime64[M]')

# %%
df.groupby(['transaction_month'])['user_id'].agg(['count','nunique'])
# Out:
#                    count  nunique
# transaction_month
# 2015-01-01          4058     3951
# 2015-02-01          4932     4777
# 2015-03-01          5824     5599
# 2015-04-01          6102     5862
# 2015-05-01          6339     6063
# 2015-06-01          6829     6480
# 2015-07-01          7520     7166
# 2015-08-01          8598     8110
# 2015-09-01          8468     7964
# 2015-10-01         10492     9743
# 2015-11-01          7695     7317

# %% [markdown]
# Посмотрим количество уникальных клиентов.

# %%
df['user_id'].nunique()
# Out:
# 48214

# %% [markdown]
# Количество месяцев.

# %%
len(df.groupby(['reg_month'])['user_id'].agg(['count','nunique']))
# Out:
# 47

# %% [markdown]
# Для каждого пользователя сделаем месяц его жизни.

# %% [markdown]
# Посмотрим есть ли отрицательные user_id. Кажется, их генерировали из нормального распределения. Доход тоже сгенерирован нормально, как и id заказов.

# %%
df['user_id'].hist()
# Out:
# <AxesSubplot:>

# %%
df['revenue'].hist()
# Out:
# <AxesSubplot:>

# %%
df['order_id'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Возьмем минимальный месяц регистрации юзеров.

# %%
users = df.groupby('user_id')['reg_month'].min().reset_index()
users
# Out:
#        user_id  reg_month
# 0       -37599 2015-01-01
# 1       -32239 2015-11-01
# 2       -29822 2015-07-01
# 3       -29531 2014-09-01
# 4       -25337 2015-04-01
# ...        ...        ...
# 48209   128964 2015-10-01
# 48210   130617 2015-02-01
# 48211   131071 2012-04-01
# 48212   132484 2015-06-01
# 48213   138987 2014-10-01
#
# [48214 rows x 2 columns]

# %%
len(df.groupby(['transaction_month'])['user_id'].agg(['count','nunique']))
# Out:
# 11

# %%
min_date = df['transaction_month'].min()
max_date = df['transaction_month'].max()

# %%
min_date
# Out:
# Timestamp('2015-01-01 00:00:00')

# %%
max_date
# Out:
# Timestamp('2015-11-01 00:00:00')

# %% [markdown]
# Возьмем минимальную и максимальную дату и сделаем календарь.

# %%
month = pd.DataFrame(pd.date_range(min_date,max_date,freq='MS'))
month
# Out:
#             0
# 0  2015-01-01
# 1  2015-02-01
# 2  2015-03-01
# 3  2015-04-01
# 4  2015-05-01
# 5  2015-06-01
# 6  2015-07-01
# 7  2015-08-01
# 8  2015-09-01
# 9  2015-10-01
# 10 2015-11-01

# %%
month.columns = ['month']

# %% [markdown]
# Сделаем cross join таблицы month с таблицей users.

# %%
user['key'] = 1
month['key'] = 1

# %%
template = user.merge(month,on='key')[['user_id','reg_month','month']]
template
# Out:
#         user_id  reg_month      month
# 0        -37599 2015-01-01 2015-01-01
# 1        -37599 2015-01-01 2015-02-01
# 2        -37599 2015-01-01 2015-03-01
# 3        -37599 2015-01-01 2015-04-01
# 4        -37599 2015-01-01 2015-05-01
# ...         ...        ...        ...
# 530349   138987 2014-10-01 2015-07-01
# 530350   138987 2014-10-01 2015-08-01
# 530351   138987 2014-10-01 2015-09-01
# 530352   138987 2014-10-01 2015-10-01
# 530353   138987 2014-10-01 2015-11-01
#
# [530354 rows x 3 columns]

# %%
template = template[template['month'] >= template['reg_month']]
template
# Out:
#         user_id  reg_month      month
# 0        -37599 2015-01-01 2015-01-01
# 1        -37599 2015-01-01 2015-02-01
# 2        -37599 2015-01-01 2015-03-01
# 3        -37599 2015-01-01 2015-04-01
# 4        -37599 2015-01-01 2015-05-01
# ...         ...        ...        ...
# 530349   138987 2014-10-01 2015-07-01
# 530350   138987 2014-10-01 2015-08-01
# 530351   138987 2014-10-01 2015-09-01
# 530352   138987 2014-10-01 2015-10-01
# 530353   138987 2014-10-01 2015-11-01
#
# [467625 rows x 3 columns]

# %%
trans_month = df.groupby(['user_id','transaction_month'])['revenue'].sum().reset_index()
trans_month
# Out:
#        user_id transaction_month  revenue
# 0       -37599        2015-03-01     1182
# 1       -32239        2015-11-01      727
# 2       -29822        2015-09-01      908
# 3       -29531        2015-06-01     1462
# 4       -25337        2015-07-01      899
# ...        ...               ...      ...
# 73027   128964        2015-10-01     1049
# 73028   130617        2015-06-01     1295
# 73029   131071        2015-10-01      856
# 73030   132484        2015-08-01      747
# 73031   138987        2015-06-01     1034
#
# [73032 rows x 3 columns]

# %%
trans_month.columns = ['user_id','month','revenue']

# %%
report = template.merge(trans_month,on=['user_id','month'],how='left')
report
# Out:
#         user_id  reg_month      month  revenue
# 0        -37599 2015-01-01 2015-01-01      NaN
# 1        -37599 2015-01-01 2015-02-01      NaN
# 2        -37599 2015-01-01 2015-03-01   1182.0
# 3        -37599 2015-01-01 2015-04-01      NaN
# 4        -37599 2015-01-01 2015-05-01      NaN
# ...         ...        ...        ...      ...
# 467620   138987 2014-10-01 2015-07-01      NaN
# 467621   138987 2014-10-01 2015-08-01      NaN
# 467622   138987 2014-10-01 2015-09-01      NaN
# 467623   138987 2014-10-01 2015-10-01      NaN
# 467624   138987 2014-10-01 2015-11-01      NaN
#
# [467625 rows x 4 columns]

# %%
report['active'] = (report['revenue'] > 0)*1
report
# Out:
#         user_id  reg_month      month  revenue  active
# 0        -37599 2015-01-01 2015-01-01      NaN       0
# 1        -37599 2015-01-01 2015-02-01      NaN       0
# 2        -37599 2015-01-01 2015-03-01   1182.0       1
# 3        -37599 2015-01-01 2015-04-01      NaN       0
# 4        -37599 2015-01-01 2015-05-01      NaN       0
# ...         ...        ...        ...      ...     ...
# 467620   138987 2014-10-01 2015-07-01      NaN       0
# 467621   138987 2014-10-01 2015-08-01      NaN       0
# 467622   138987 2014-10-01 2015-09-01      NaN       0
# 467623   138987 2014-10-01 2015-10-01      NaN       0
# 467624   138987 2014-10-01 2015-11-01      NaN       0
#
# [467625 rows x 5 columns]

# %% [markdown]
# Сделаем сводные таблицы.

# %%
# кол-во людей
report.pivot_table(index='reg_month',columns='month',values='active',aggfunc='count')
# Out:
# month       2015-01-01  2015-02-01  2015-03-01  2015-04-01  2015-05-01  \
# reg_month
# 1900-01-01        53.0        53.0        53.0        53.0        53.0
# 2012-02-01         9.0         9.0         9.0         9.0         9.0
# 2012-03-01       361.0       361.0       361.0       361.0       361.0
# 2012-04-01       369.0       369.0       369.0       369.0       369.0
# 2012-05-01       298.0       298.0       298.0       298.0       298.0
# 2012-06-01       436.0       436.0       436.0       436.0       436.0
# 2012-07-01       359.0       359.0       359.0       359.0       359.0
# 2012-08-01       264.0       264.0       264.0       264.0       264.0
# 2012-09-01       345.0       345.0       345.0       345.0       345.0
# 2012-10-01       353.0       353.0       353.0       353.0       353.0
# 2012-11-01       256.0       256.0       256.0       256.0       256.0
# 2012-12-01       505.0       505.0       505.0       505.0       505.0
# 2013-01-01       408.0       408.0       408.0       408.0       408.0
# 2013-02-01       626.0       626.0       626.0       626.0       626.0
# 2013-03-01      1092.0      1092.0      1092.0      1092.0      1092.0
# 2013-04-01       767.0       767.0       767.0       767.0       767.0
# 2013-05-01       976.0       976.0       976.0       976.0       976.0
# 2013-06-01       837.0       837.0       837.0       837.0       837.0
# 2013-07-01       965.0       965.0       965.0       965.0       965.0
# 2013-08-01      1020.0      1020.0      1020.0      1020.0      1020.0
# 2013-09-01       858.0       858.0       858.0       858.0       858.0
# 2013-10-01       688.0       688.0       688.0       688.0       688.0
# 2013-11-01       926.0       926.0       926.0       926.0       926.0
# 2013-12-01      1292.0      1292.0      1292.0      1292.0      1292.0
# 2014-01-01      1141.0      1141.0      1141.0      1141.0      1141.0
# 2014-02-01      1064.0      1064.0      1064.0      1064.0      1064.0
# 2014-03-01      1180.0      1180.0      1180.0      1180.0      1180.0
# 2014-04-01      1232.0      1232.0      1232.0      1232.0      1232.0
# 2014-05-01      1107.0      1107.0      1107.0      1107.0      1107.0
# 2014-06-01      1359.0      1359.0      1359.0      1359.0      1359.0
# 2014-07-01      1276.0      1276.0      1276.0      1276.0      1276.0
# 2014-08-01      1603.0      1603.0      1603.0      1603.0      1603.0
# 2014-09-01      1746.0      1746.0      1746.0      1746.0      1746.0
# 2014-10-01      1922.0      1922.0      1922.0      1922.0      1922.0
# 2014-11-01      1834.0      1834.0      1834.0      1834.0      1834.0
# 2014-12-01      2757.0      2757.0      2757.0      2757.0      2757.0
# 2015-01-01      2292.0      2292.0      2292.0      2292.0      2292.0
# 2015-02-01         NaN      1957.0      1957.0      1957.0      1957.0
# 2015-03-01         NaN         NaN      1828.0      1828.0      1828.0
# 2015-04-01         NaN         NaN         NaN      1632.0      1632.0
# 2015-05-01         NaN         NaN         NaN         NaN      1270.0
# 2015-06-01         NaN         NaN         NaN         NaN         NaN
# 2015-07-01         NaN         NaN         NaN         NaN         NaN
# 2015-08-01         NaN         NaN         NaN         NaN         NaN
# 2015-09-01         NaN         NaN         NaN         NaN         NaN
# 2015-10-01         NaN         NaN         NaN         NaN         NaN
# 2015-11-01         NaN         NaN         NaN         NaN         NaN
#
# month       2015-06-01  2015-07-01  2015-08-01  2015-09-01  2015-10-01  \
# reg_month
# 1900-01-01        53.0        53.0        53.0        53.0        53.0
# 2012-02-01         9.0         9.0         9.0         9.0         9.0
# 2012-03-01       361.0       361.0       361.0       361.0       361.0
# 2012-04-01       369.0       369.0       369.0       369.0       369.0
# 2012-05-01       298.0       298.0       298.0       298.0       298.0
# 2012-06-01       436.0       436.0       436.0       436.0       436.0
# 2012-07-01       359.0       359.0       359.0       359.0       359.0
# 2012-08-01       264.0       264.0       264.0       264.0       264.0
# 2012-09-01       345.0       345.0       345.0       345.0       345.0
# 2012-10-01       353.0       353.0       353.0       353.0       353.0
# 2012-11-01       256.0       256.0       256.0       256.0       256.0
# 2012-12-01       505.0       505.0       505.0       505.0       505.0
# 2013-01-01       408.0       408.0       408.0       408.0       408.0
# 2013-02-01       626.0       626.0       626.0       626.0       626.0
# 2013-03-01      1092.0      1092.0      1092.0      1092.0      1092.0
# 2013-04-01       767.0       767.0       767.0       767.0       767.0
# 2013-05-01       976.0       976.0       976.0       976.0       976.0
# 2013-06-01       837.0       837.0       837.0       837.0       837.0
# 2013-07-01       965.0       965.0       965.0       965.0       965.0
# 2013-08-01      1020.0      1020.0      1020.0      1020.0      1020.0
# 2013-09-01       858.0       858.0       858.0       858.0       858.0
# 2013-10-01       688.0       688.0       688.0       688.0       688.0
# 2013-11-01       926.0       926.0       926.0       926.0       926.0
# 2013-12-01      1292.0      1292.0      1292.0      1292.0      1292.0
# 2014-01-01      1141.0      1141.0      1141.0      1141.0      1141.0
# 2014-02-01      1064.0      1064.0      1064.0      1064.0      1064.0
# 2014-03-01      1180.0      1180.0      1180.0      1180.0      1180.0
# 2014-04-01      1232.0      1232.0      1232.0      1232.0      1232.0
# 2014-05-01      1107.0      1107.0      1107.0      1107.0      1107.0
# 2014-06-01      1359.0      1359.0      1359.0      1359.0      1359.0
# 2014-07-01      1276.0      1276.0      1276.0      1276.0      1276.0
# 2014-08-01      1603.0      1603.0      1603.0      1603.0      1603.0
# 2014-09-01      1746.0      1746.0      1746.0      1746.0      1746.0
# 2014-10-01      1922.0      1922.0      1922.0      1922.0      1922.0
# 2014-11-01      1834.0      1834.0      1834.0      1834.0      1834.0
# 2014-12-01      2757.0      2757.0      2757.0      2757.0      2757.0
# 2015-01-01      2292.0      2292.0      2292.0      2292.0      2292.0
# 2015-02-01      1957.0      1957.0      1957.0      1957.0      1957.0
# 2015-03-01      1828.0      1828.0      1828.0      1828.0      1828.0
# 2015-04-01      1632.0      1632.0      1632.0      1632.0      1632.0
# 2015-05-01      1270.0      1270.0      1270.0      1270.0      1270.0
# 2015-06-01      1609.0      1609.0      1609.0      1609.0      1609.0
# 2015-07-01         NaN      1865.0      1865.0      1865.0      1865.0
# 2015-08-01         NaN         NaN      1370.0      1370.0      1370.0
# 2015-09-01         NaN         NaN         NaN       962.0       962.0
# 2015-10-01         NaN         NaN         NaN         NaN       831.0
# 2015-11-01         NaN         NaN         NaN         NaN         NaN
#
# month       2015-11-01
# reg_month
# 1900-01-01        53.0
# 2012-02-01         9.0
# 2012-03-01       361.0
# 2012-04-01       369.0
# 2012-05-01       298.0
# 2012-06-01       436.0
# 2012-07-01       359.0
# 2012-08-01       264.0
# 2012-09-01       345.0
# 2012-10-01       353.0
# 2012-11-01       256.0
# 2012-12-01       505.0
# 2013-01-01       408.0
# 2013-02-01       626.0
# 2013-03-01      1092.0
# 2013-04-01       767.0
# 2013-05-01       976.0
# 2013-06-01       837.0
# 2013-07-01       965.0
# 2013-08-01      1020.0
# 2013-09-01       858.0
# 2013-10-01       688.0
# 2013-11-01       926.0
# 2013-12-01      1292.0
# 2014-01-01      1141.0
# 2014-02-01      1064.0
# 2014-03-01      1180.0
# 2014-04-01      1232.0
# 2014-05-01      1107.0
# 2014-06-01      1359.0
# 2014-07-01      1276.0
# 2014-08-01      1603.0
# 2014-09-01      1746.0
# 2014-10-01      1922.0
# 2014-11-01      1834.0
# 2014-12-01      2757.0
# 2015-01-01      2292.0
# 2015-02-01      1957.0
# 2015-03-01      1828.0
# 2015-04-01      1632.0
# 2015-05-01      1270.0
# 2015-06-01      1609.0
# 2015-07-01      1865.0
# 2015-08-01      1370.0
# 2015-09-01       962.0
# 2015-10-01       831.0
# 2015-11-01       314.0

# %%
# кол-во активных людей
report.pivot_table(index='reg_month',columns='month',values='active',aggfunc='sum')
# Out:
# month       2015-01-01  2015-02-01  2015-03-01  2015-04-01  2015-05-01  \
# reg_month
# 1900-01-01         8.0         9.0        18.0         8.0         9.0
# 2012-02-01         1.0         2.0         1.0         0.0         4.0
# 2012-03-01        53.0        57.0        45.0        55.0        53.0
# 2012-04-01        54.0        51.0        85.0        62.0        62.0
# 2012-05-01        29.0        47.0        50.0        56.0        56.0
# 2012-06-01        51.0        62.0        64.0        90.0        75.0
# 2012-07-01        49.0        51.0        55.0        63.0        60.0
# 2012-08-01        21.0        40.0        49.0        53.0        40.0
# 2012-09-01        54.0        45.0        53.0        66.0        57.0
# 2012-10-01        48.0        45.0        62.0        63.0        64.0
# 2012-11-01        43.0        37.0        41.0        52.0        35.0
# 2012-12-01        64.0        76.0        75.0        80.0        67.0
# 2013-01-01        46.0        60.0        66.0        74.0        75.0
# 2013-02-01        73.0        86.0       104.0       101.0       111.0
# 2013-03-01       133.0       150.0       190.0       173.0       198.0
# 2013-04-01        99.0       108.0       121.0       128.0       120.0
# 2013-05-01       120.0       156.0       169.0       160.0       173.0
# 2013-06-01       107.0       127.0       138.0       134.0       133.0
# 2013-07-01       121.0       131.0       130.0       146.0       168.0
# 2013-08-01       144.0       162.0       159.0       145.0       140.0
# 2013-09-01       114.0       121.0       139.0       142.0       139.0
# 2013-10-01        91.0        84.0       113.0       118.0       107.0
# 2013-11-01       101.0       161.0       141.0       127.0       131.0
# 2013-12-01       139.0       178.0       196.0       211.0       188.0
# 2014-01-01       125.0       145.0       184.0       191.0       161.0
# 2014-02-01       112.0       139.0       164.0       157.0       140.0
# 2014-03-01       129.0       168.0       174.0       188.0       155.0
# 2014-04-01       135.0       171.0       160.0       185.0       187.0
# 2014-05-01       124.0       134.0       170.0       153.0       154.0
# 2014-06-01       158.0       158.0       191.0       164.0       207.0
# 2014-07-01       137.0       147.0       170.0       174.0       168.0
# 2014-08-01       185.0       207.0       198.0       218.0       229.0
# 2014-09-01       162.0       208.0       251.0       223.0       235.0
# 2014-10-01       190.0       222.0       243.0       249.0       266.0
# 2014-11-01       186.0       222.0       210.0       225.0       238.0
# 2014-12-01       276.0       284.0       346.0       326.0       348.0
# 2015-01-01       268.0       266.0       297.0       267.0       264.0
# 2015-02-01         NaN       260.0       277.0       266.0       238.0
# 2015-03-01         NaN         NaN       300.0       253.0       237.0
# 2015-04-01         NaN         NaN         NaN       316.0       258.0
# 2015-05-01         NaN         NaN         NaN         NaN       313.0
# 2015-06-01         NaN         NaN         NaN         NaN         NaN
# 2015-07-01         NaN         NaN         NaN         NaN         NaN
# 2015-08-01         NaN         NaN         NaN         NaN         NaN
# 2015-09-01         NaN         NaN         NaN         NaN         NaN
# 2015-10-01         NaN         NaN         NaN         NaN         NaN
# 2015-11-01         NaN         NaN         NaN         NaN         NaN
#
# month       2015-06-01  2015-07-01  2015-08-01  2015-09-01  2015-10-01  \
# reg_month
# 1900-01-01        13.0         6.0         5.0         5.0         9.0
# 2012-02-01         2.0         2.0         2.0         2.0         0.0
# 2012-03-01        66.0        61.0        70.0        64.0       106.0
# 2012-04-01        63.0        63.0        61.0        65.0        89.0
# 2012-05-01        54.0        53.0        74.0        52.0        63.0
# 2012-06-01        70.0        71.0        69.0        86.0       106.0
# 2012-07-01        55.0        65.0        69.0        53.0        94.0
# 2012-08-01        40.0        51.0        57.0        54.0        66.0
# 2012-09-01        59.0        50.0        60.0        57.0        67.0
# 2012-10-01        54.0        55.0        75.0        56.0        77.0
# 2012-11-01        35.0        41.0        47.0        49.0        53.0
# 2012-12-01        87.0        87.0        99.0        88.0       127.0
# 2013-01-01        74.0        71.0        77.0        77.0        95.0
# 2013-02-01       102.0       117.0       108.0       129.0       125.0
# 2013-03-01       166.0       204.0       197.0       208.0       249.0
# 2013-04-01       132.0       128.0       125.0       148.0       167.0
# 2013-05-01       166.0       202.0       182.0       160.0       204.0
# 2013-06-01       118.0       143.0       162.0       138.0       183.0
# 2013-07-01       156.0       166.0       168.0       168.0       228.0
# 2013-08-01       156.0       164.0       184.0       184.0       227.0
# 2013-09-01       138.0       131.0       159.0       149.0       183.0
# 2013-10-01       110.0       102.0       110.0       116.0       155.0
# 2013-11-01       138.0       152.0       162.0       149.0       197.0
# 2013-12-01       207.0       213.0       233.0       227.0       254.0
# 2014-01-01       177.0       171.0       182.0       213.0       231.0
# 2014-02-01       167.0       158.0       177.0       171.0       235.0
# 2014-03-01       169.0       198.0       209.0       198.0       232.0
# 2014-04-01       183.0       196.0       198.0       180.0       262.0
# 2014-05-01       183.0       158.0       180.0       184.0       223.0
# 2014-06-01       206.0       180.0       247.0       217.0       241.0
# 2014-07-01       164.0       226.0       203.0       203.0       244.0
# 2014-08-01       241.0       253.0       236.0       233.0       284.0
# 2014-09-01       247.0       259.0       286.0       276.0       308.0
# 2014-10-01       268.0       269.0       275.0       300.0       342.0
# 2014-11-01       229.0       247.0       253.0       285.0       334.0
# 2014-12-01       342.0       400.0       375.0       381.0       452.0
# 2015-01-01       286.0       271.0       301.0       289.0       341.0
# 2015-02-01       239.0       234.0       242.0       292.0       319.0
# 2015-03-01       233.0       253.0       266.0       254.0       312.0
# 2015-04-01       236.0       222.0       263.0       224.0       274.0
# 2015-05-01       234.0       196.0       173.0       194.0       202.0
# 2015-06-01       415.0       348.0       290.0       271.0       305.0
# 2015-07-01         NaN       528.0       618.0       334.0       339.0
# 2015-08-01         NaN         NaN       580.0       368.0       305.0
# 2015-09-01         NaN         NaN         NaN       413.0       367.0
# 2015-10-01         NaN         NaN         NaN         NaN       467.0
# 2015-11-01         NaN         NaN         NaN         NaN         NaN
#
# month       2015-11-01
# reg_month
# 1900-01-01         5.0
# 2012-02-01         2.0
# 2012-03-01        58.0
# 2012-04-01        66.0
# 2012-05-01        54.0
# 2012-06-01        77.0
# 2012-07-01        67.0
# 2012-08-01        50.0
# 2012-09-01        50.0
# 2012-10-01        58.0
# 2012-11-01        38.0
# 2012-12-01        81.0
# 2013-01-01        55.0
# 2013-02-01       116.0
# 2013-03-01       164.0
# 2013-04-01       103.0
# 2013-05-01       139.0
# 2013-06-01       140.0
# 2013-07-01       137.0
# 2013-08-01       168.0
# 2013-09-01       130.0
# 2013-10-01       107.0
# 2013-11-01       133.0
# 2013-12-01       189.0
# 2014-01-01       182.0
# 2014-02-01       139.0
# 2014-03-01       177.0
# 2014-04-01       184.0
# 2014-05-01       153.0
# 2014-06-01       203.0
# 2014-07-01       190.0
# 2014-08-01       212.0
# 2014-09-01       225.0
# 2014-10-01       235.0
# 2014-11-01       235.0
# 2014-12-01       361.0
# 2015-01-01       262.0
# 2015-02-01       206.0
# 2015-03-01       214.0
# 2015-04-01       208.0
# 2015-05-01       168.0
# 2015-06-01       228.0
# 2015-07-01       232.0
# 2015-08-01       216.0
# 2015-09-01       213.0
# 2015-10-01       373.0
# 2015-11-01       314.0

# %%
# процент актвных людей 
retention = report.pivot_table(index='reg_month',columns='month',values='active',aggfunc='mean')

# %%
retention
# Out:
# month       2015-01-01  2015-02-01  2015-03-01  2015-04-01  2015-05-01  \
# reg_month
# 1900-01-01    0.150943    0.169811    0.339623    0.150943    0.169811
# 2012-02-01    0.111111    0.222222    0.111111    0.000000    0.444444
# 2012-03-01    0.146814    0.157895    0.124654    0.152355    0.146814
# 2012-04-01    0.146341    0.138211    0.230352    0.168022    0.168022
# 2012-05-01    0.097315    0.157718    0.167785    0.187919    0.187919
# 2012-06-01    0.116972    0.142202    0.146789    0.206422    0.172018
# 2012-07-01    0.136490    0.142061    0.153203    0.175487    0.167131
# 2012-08-01    0.079545    0.151515    0.185606    0.200758    0.151515
# 2012-09-01    0.156522    0.130435    0.153623    0.191304    0.165217
# 2012-10-01    0.135977    0.127479    0.175637    0.178470    0.181303
# 2012-11-01    0.167969    0.144531    0.160156    0.203125    0.136719
# 2012-12-01    0.126733    0.150495    0.148515    0.158416    0.132673
# 2013-01-01    0.112745    0.147059    0.161765    0.181373    0.183824
# 2013-02-01    0.116613    0.137380    0.166134    0.161342    0.177316
# 2013-03-01    0.121795    0.137363    0.173993    0.158425    0.181319
# 2013-04-01    0.129074    0.140808    0.157757    0.166884    0.156454
# 2013-05-01    0.122951    0.159836    0.173156    0.163934    0.177254
# 2013-06-01    0.127838    0.151732    0.164875    0.160096    0.158901
# 2013-07-01    0.125389    0.135751    0.134715    0.151295    0.174093
# 2013-08-01    0.141176    0.158824    0.155882    0.142157    0.137255
# 2013-09-01    0.132867    0.141026    0.162005    0.165501    0.162005
# 2013-10-01    0.132267    0.122093    0.164244    0.171512    0.155523
# 2013-11-01    0.109071    0.173866    0.152268    0.137149    0.141469
# 2013-12-01    0.107585    0.137771    0.151703    0.163313    0.145511
# 2014-01-01    0.109553    0.127082    0.161262    0.167397    0.141104
# 2014-02-01    0.105263    0.130639    0.154135    0.147556    0.131579
# 2014-03-01    0.109322    0.142373    0.147458    0.159322    0.131356
# 2014-04-01    0.109578    0.138799    0.129870    0.150162    0.151786
# 2014-05-01    0.112014    0.121048    0.153568    0.138211    0.139115
# 2014-06-01    0.116262    0.116262    0.140545    0.120677    0.152318
# 2014-07-01    0.107367    0.115204    0.133229    0.136364    0.131661
# 2014-08-01    0.115409    0.129133    0.123518    0.135995    0.142857
# 2014-09-01    0.092784    0.119129    0.143757    0.127721    0.134593
# 2014-10-01    0.098855    0.115505    0.126431    0.129553    0.138398
# 2014-11-01    0.101418    0.121047    0.114504    0.122683    0.129771
# 2014-12-01    0.100109    0.103011    0.125499    0.118244    0.126224
# 2015-01-01    0.116928    0.116056    0.129581    0.116492    0.115183
# 2015-02-01         NaN    0.132856    0.141543    0.135922    0.121615
# 2015-03-01         NaN         NaN    0.164114    0.138403    0.129650
# 2015-04-01         NaN         NaN         NaN    0.193627    0.158088
# 2015-05-01         NaN         NaN         NaN         NaN    0.246457
# 2015-06-01         NaN         NaN         NaN         NaN         NaN
# 2015-07-01         NaN         NaN         NaN         NaN         NaN
# 2015-08-01         NaN         NaN         NaN         NaN         NaN
# 2015-09-01         NaN         NaN         NaN         NaN         NaN
# 2015-10-01         NaN         NaN         NaN         NaN         NaN
# 2015-11-01         NaN         NaN         NaN         NaN         NaN
#
# month       2015-06-01  2015-07-01  2015-08-01  2015-09-01  2015-10-01  \
# reg_month
# 1900-01-01    0.245283    0.113208    0.094340    0.094340    0.169811
# 2012-02-01    0.222222    0.222222    0.222222    0.222222    0.000000
# 2012-03-01    0.182825    0.168975    0.193906    0.177285    0.293629
# 2012-04-01    0.170732    0.170732    0.165312    0.176152    0.241192
# 2012-05-01    0.181208    0.177852    0.248322    0.174497    0.211409
# 2012-06-01    0.160550    0.162844    0.158257    0.197248    0.243119
# 2012-07-01    0.153203    0.181058    0.192201    0.147632    0.261838
# 2012-08-01    0.151515    0.193182    0.215909    0.204545    0.250000
# 2012-09-01    0.171014    0.144928    0.173913    0.165217    0.194203
# 2012-10-01    0.152975    0.155807    0.212465    0.158640    0.218130
# 2012-11-01    0.136719    0.160156    0.183594    0.191406    0.207031
# 2012-12-01    0.172277    0.172277    0.196040    0.174257    0.251485
# 2013-01-01    0.181373    0.174020    0.188725    0.188725    0.232843
# 2013-02-01    0.162939    0.186901    0.172524    0.206070    0.199681
# 2013-03-01    0.152015    0.186813    0.180403    0.190476    0.228022
# 2013-04-01    0.172099    0.166884    0.162973    0.192960    0.217731
# 2013-05-01    0.170082    0.206967    0.186475    0.163934    0.209016
# 2013-06-01    0.140980    0.170848    0.193548    0.164875    0.218638
# 2013-07-01    0.161658    0.172021    0.174093    0.174093    0.236269
# 2013-08-01    0.152941    0.160784    0.180392    0.180392    0.222549
# 2013-09-01    0.160839    0.152681    0.185315    0.173660    0.213287
# 2013-10-01    0.159884    0.148256    0.159884    0.168605    0.225291
# 2013-11-01    0.149028    0.164147    0.174946    0.160907    0.212743
# 2013-12-01    0.160217    0.164861    0.180341    0.175697    0.196594
# 2014-01-01    0.155127    0.149869    0.159509    0.186678    0.202454
# 2014-02-01    0.156955    0.148496    0.166353    0.160714    0.220865
# 2014-03-01    0.143220    0.167797    0.177119    0.167797    0.196610
# 2014-04-01    0.148539    0.159091    0.160714    0.146104    0.212662
# 2014-05-01    0.165312    0.142728    0.162602    0.166215    0.201445
# 2014-06-01    0.151582    0.132450    0.181751    0.159676    0.177336
# 2014-07-01    0.128527    0.177116    0.159091    0.159091    0.191223
# 2014-08-01    0.150343    0.157829    0.147224    0.145352    0.177168
# 2014-09-01    0.141466    0.148339    0.163803    0.158076    0.176403
# 2014-10-01    0.139438    0.139958    0.143080    0.156087    0.177940
# 2014-11-01    0.124864    0.134678    0.137950    0.155398    0.182116
# 2014-12-01    0.124048    0.145085    0.136017    0.138194    0.163946
# 2015-01-01    0.124782    0.118237    0.131326    0.126091    0.148778
# 2015-02-01    0.122126    0.119571    0.123659    0.149208    0.163005
# 2015-03-01    0.127462    0.138403    0.145514    0.138950    0.170678
# 2015-04-01    0.144608    0.136029    0.161152    0.137255    0.167892
# 2015-05-01    0.184252    0.154331    0.136220    0.152756    0.159055
# 2015-06-01    0.257924    0.216283    0.180236    0.168428    0.189559
# 2015-07-01         NaN    0.283110    0.331367    0.179088    0.181769
# 2015-08-01         NaN         NaN    0.423358    0.268613    0.222628
# 2015-09-01         NaN         NaN         NaN    0.429314    0.381497
# 2015-10-01         NaN         NaN         NaN         NaN    0.561974
# 2015-11-01         NaN         NaN         NaN         NaN         NaN
#
# month       2015-11-01
# reg_month
# 1900-01-01    0.094340
# 2012-02-01    0.222222
# 2012-03-01    0.160665
# 2012-04-01    0.178862
# 2012-05-01    0.181208
# 2012-06-01    0.176606
# 2012-07-01    0.186630
# 2012-08-01    0.189394
# 2012-09-01    0.144928
# 2012-10-01    0.164306
# 2012-11-01    0.148438
# 2012-12-01    0.160396
# 2013-01-01    0.134804
# 2013-02-01    0.185304
# 2013-03-01    0.150183
# 2013-04-01    0.134289
# 2013-05-01    0.142418
# 2013-06-01    0.167264
# 2013-07-01    0.141969
# 2013-08-01    0.164706
# 2013-09-01    0.151515
# 2013-10-01    0.155523
# 2013-11-01    0.143629
# 2013-12-01    0.146285
# 2014-01-01    0.159509
# 2014-02-01    0.130639
# 2014-03-01    0.150000
# 2014-04-01    0.149351
# 2014-05-01    0.138211
# 2014-06-01    0.149375
# 2014-07-01    0.148903
# 2014-08-01    0.132252
# 2014-09-01    0.128866
# 2014-10-01    0.122268
# 2014-11-01    0.128135
# 2014-12-01    0.130939
# 2015-01-01    0.114311
# 2015-02-01    0.105263
# 2015-03-01    0.117068
# 2015-04-01    0.127451
# 2015-05-01    0.132283
# 2015-06-01    0.141703
# 2015-07-01    0.124397
# 2015-08-01    0.157664
# 2015-09-01    0.221414
# 2015-10-01    0.448857
# 2015-11-01    1.000000

# %% [markdown]
# Можно увидеть, что в июле 15 года наблюдается прирост числа новых пользователей.В последующих месяцах также наблюается прирост. Посмтроим тепловую карту.

# %%
import numpy as np
import seaborn as sns
uniform_data = np.random.rand(10, 12)
#ax = sns.heatmap(uniform_data)

# %%
sns.set(font_scale=2,style="whitegrid",rc={'figure.figsize':(12,6)} )

# %%
sns.heatmap(retention)
# Out:
# <AxesSubplot:xlabel='month', ylabel='reg_month'>

# %% [markdown]
# Посмотрим только 15 год. Посчитаем разницу между transaction month и reg date

# %%
report['lifetime'] = ((report['month'] - report['reg_month'])/np.timedelta64(1, 'M')).round().astype(int)

# %%
report[report['user_id'] == 128006]
# Out:
#         user_id  reg_month      month  revenue  active  lifetime
# 467563   128006 2015-01-01 2015-01-01      NaN       0         0
# 467564   128006 2015-01-01 2015-02-01    539.0       1         1
# 467565   128006 2015-01-01 2015-03-01      NaN       0         2
# 467566   128006 2015-01-01 2015-04-01      NaN       0         3
# 467567   128006 2015-01-01 2015-05-01      NaN       0         4
# 467568   128006 2015-01-01 2015-06-01      NaN       0         5
# 467569   128006 2015-01-01 2015-07-01      NaN       0         6
# 467570   128006 2015-01-01 2015-08-01      NaN       0         7
# 467571   128006 2015-01-01 2015-09-01      NaN       0         8
# 467572   128006 2015-01-01 2015-10-01      NaN       0         9
# 467573   128006 2015-01-01 2015-11-01      NaN       0        10

# %%
report['reg_month_str'] = report['reg_month'].dt.strftime('%Y-%m')

# %%
retention = report[report['reg_month'] >= '2015-01-01'].pivot_table(index='reg_month',columns='lifetime',values='active',aggfunc='mean')
retention
# Out:
# lifetime          0         1         2         3         4         5   \
# reg_month
# 2015-01-01  0.116928  0.116056  0.129581  0.116492  0.115183  0.124782
# 2015-02-01  0.132856  0.141543  0.135922  0.121615  0.122126  0.119571
# 2015-03-01  0.164114  0.138403  0.129650  0.127462  0.138403  0.145514
# 2015-04-01  0.193627  0.158088  0.144608  0.136029  0.161152  0.137255
# 2015-05-01  0.246457  0.184252  0.154331  0.136220  0.152756  0.159055
# 2015-06-01  0.257924  0.216283  0.180236  0.168428  0.189559  0.141703
# 2015-07-01  0.283110  0.331367  0.179088  0.181769  0.124397       NaN
# 2015-08-01  0.423358  0.268613  0.222628  0.157664       NaN       NaN
# 2015-09-01  0.429314  0.381497  0.221414       NaN       NaN       NaN
# 2015-10-01  0.561974  0.448857       NaN       NaN       NaN       NaN
# 2015-11-01  1.000000       NaN       NaN       NaN       NaN       NaN
#
# lifetime          6         7         8         9         10
# reg_month
# 2015-01-01  0.118237  0.131326  0.126091  0.148778  0.114311
# 2015-02-01  0.123659  0.149208  0.163005  0.105263       NaN
# 2015-03-01  0.138950  0.170678  0.117068       NaN       NaN
# 2015-04-01  0.167892  0.127451       NaN       NaN       NaN
# 2015-05-01  0.132283       NaN       NaN       NaN       NaN
# 2015-06-01       NaN       NaN       NaN       NaN       NaN
# 2015-07-01       NaN       NaN       NaN       NaN       NaN
# 2015-08-01       NaN       NaN       NaN       NaN       NaN
# 2015-09-01       NaN       NaN       NaN       NaN       NaN
# 2015-10-01       NaN       NaN       NaN       NaN       NaN
# 2015-11-01       NaN       NaN       NaN       NaN       NaN

# %%
sns.heatmap(retention)
# Out:
# <AxesSubplot:xlabel='lifetime', ylabel='reg_month'>

# %% [markdown]
# retention повышается с июля.

# %%
import sqlite3

# %%
con = sqlite3.connect('db')

# %%
cur = con.cursor()

# %%
def select(sql):
  return pd.read_sql(sql,con)

# %%
df = pd.read_csv(r'C:\Users\Lily_B\Documents\аналитика на python\analyst_test_transactions_db.csv')

# %%
df['reg_date'] = pd.to_datetime(df['reg_date'],format='%Y-%m-%d')
df['transaction_date'] = pd.to_datetime(df['transaction_date'],format='%Y-%m-%d')

# %%
df.to_sql('trans',con,index=False,if_exists='replace')

# %%
sql = ''' select * from trans t'''

# %%
select(sql)
# Out:
#        user_id  order_id             reg_date     transaction_date  revenue
# 0        57562   94545.0  2013-12-22 00:00:00  2015-07-16 00:00:00     1088
# 1        40047   81824.0  2013-11-24 00:00:00  2015-01-19 00:00:00     1027
# 2        48153  144851.0  2015-07-03 00:00:00  2015-10-29 00:00:00      601
# 3        54591  116111.0  2013-07-12 00:00:00  2015-04-30 00:00:00      881
# 4        39789  134943.0  2013-05-25 00:00:00  2015-07-21 00:00:00      984
# ...        ...       ...                  ...                  ...      ...
# 76852    36921  163682.0  2015-01-15 00:00:00  2015-03-28 00:00:00     1095
# 76853    31360  145146.0  2015-01-04 00:00:00  2015-08-09 00:00:00      547
# 76854    56195    8929.0  2012-09-18 00:00:00  2015-11-12 00:00:00      850
# 76855    46362   78673.0  2015-02-20 00:00:00  2015-07-21 00:00:00      356
# 76856    14872  106067.0  2015-03-13 00:00:00  2015-04-13 00:00:00     1114
#
# [76857 rows x 5 columns]
